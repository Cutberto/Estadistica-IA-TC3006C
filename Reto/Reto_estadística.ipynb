# %%
from google.colab import drive
import numpy as np
import pandas as pd
drive.mount("/content/gdrive")  
# !pwd  # show current path 

# %cd "/content/gdrive/MyDrive/IA95022"
# !ls  # show current directory
# Out:
# Mounted at /content/gdrive
# /content
# /content/gdrive/MyDrive/IA95022
#  bezdekIris.data   iris.data		     'Store Sales'    usfirms2022.csv
#  DryBeanDataset    iris.names		      train.csv       Wine
#  Index		   notebookdc8e90834b.ipynb   us2022q2a.csv

# %%
# Carga de datos
usdata = pd.read_csv('us2022q2a.csv')
usfirms = pd.read_csv('usfirms2022.csv')
# Unimos la información de ambos datasets en un solo dataframe
usfirms.columns = usfirms.columns.str.replace('Ticker', 'firm')
df = pd.merge(usfirms, usdata, on="firm")
df
# Out:
#         firm                   Name     N  Class Country\nof Origin  \
# 0       FLWS  1 800 Flowers Com Inc     1  Com A                 US
# 1       FLWS  1 800 Flowers Com Inc     1  Com A                 US
# 2       FLWS  1 800 Flowers Com Inc     1  Com A                 US
# 3       FLWS  1 800 Flowers Com Inc     1  Com A                 US
# 4       FLWS  1 800 Flowers Com Inc     1  Com A                 US
# ...      ...                    ...   ...    ...                ...
# 323811  ZNGA              Zynga Inc  3608  Com A                 US
# 323812  ZNGA              Zynga Inc  3608  Com A                 US
# 323813  ZNGA              Zynga Inc  3608  Com A                 US
# 323814  ZNGA              Zynga Inc  3608  Com A                 US
# 323815  ZNGA              Zynga Inc  3608  Com A                 US
#
#        Type of Asset Sector NAICS\nlevel 1 Exchange / Src Sector\nEconomatica  \
# 0              Stock          Retail Trade         NASDAQ               Trade
# 1              Stock          Retail Trade         NASDAQ               Trade
# 2              Stock          Retail Trade         NASDAQ               Trade
# 3              Stock          Retail Trade         NASDAQ               Trade
# 4              Stock          Retail Trade         NASDAQ               Trade
# ...              ...                   ...            ...                 ...
# 323811         Stock           Information         NASDAQ     Software & Data
# 323812         Stock           Information         NASDAQ     Software & Data
# 323813         Stock           Information         NASDAQ     Software & Data
# 323814         Stock           Information         NASDAQ     Software & Data
# 323815         Stock           Information         NASDAQ     Software & Data
#
#                           Sector NAICS\nlast available  ... totalliabilities  \
# 0                                         Retail Trade  ...          76657.0
# 1                                         Retail Trade  ...          65723.0
# 2                                         Retail Trade  ...          75163.0
# 3                                         Retail Trade  ...          88231.0
# 4                                         Retail Trade  ...          83160.0
# ...                                                ...  ...              ...
# 323811  Data Processing, Hosting, and Related Services  ...        3111600.0
# 323812  Data Processing, Hosting, and Related Services  ...        3060700.0
# 323813  Data Processing, Hosting, and Related Services  ...        3247000.0
# 323814  Data Processing, Hosting, and Related Services  ...        2953900.0
# 323815  Data Processing, Hosting, and Related Services  ...              NaN
#
#        shortdebt   longdebt  stockholderequity   adjprice  originalprice  \
# 0         4380.0     8869.0           171804.0   7.125000       7.125000
# 1         1839.0     9441.0           158918.0   5.125000       5.125000
# 2         7654.0    10916.0           136286.0   4.984375       4.984375
# 3         2157.0    10452.0           125752.0   4.125000       4.125000
# 4         4777.0    12318.0           117240.0   8.000000       8.000000
# ...          ...        ...                ...        ...            ...
# 323811   17700.0  1457000.0          3020600.0  10.630000      10.630000
# 323812   17600.0  1467600.0          3007000.0   7.530000       7.530000
# 323813   17100.0  1477200.0          3111900.0   6.400000       6.400000
# 323814   17900.0  1673700.0          2906100.0   9.240000       9.240000
# 323815       NaN        NaN                NaN   8.180000       8.180000
#
#         sharesoutstanding  fiscalmonth    year  cto
# 0               64097.913          9.0  2000.0  1.0
# 1               64170.913         12.0  2000.0  2.0
# 2               64185.913          3.0  2000.0  3.0
# 3               64187.163          6.0  2000.0  4.0
# 4               64187.163          9.0  2001.0  1.0
# ...                   ...          ...     ...  ...
# 323811        1088762.805          6.0  2021.0  2.0
# 323812        1091890.649          9.0  2021.0  3.0
# 323813        1120181.490         12.0  2021.0  4.0
# 323814        1132408.337          3.0  2022.0  1.0
# 323815        1137273.677          NaN  2022.0  2.0
#
# [323816 rows x 30 columns]

# %%
df['lprice'] = df.groupby(['firm'])['adjprice'].shift(4)
df['r'] = np.log(df['adjprice']) - np.log(df['lprice'])
df['r2']= np.log(df['adjprice']) - np.log(df.groupby(['firm'])['adjprice'].shift(4))
df.loc['ADT': 'ADTN', ['adjprice', 'lprice', 'r', 'r2']].iloc[85:96,]
# Out:
# Empty DataFrame
# Columns: [adjprice, lprice, r, r2]
# Index: []

# %%
df['qdate'] = pd.PeriodIndex(df['q'], freq="Q")

df.set_index(['firm', 'qdate'], drop = True)

df.index
df.columns
df['lprice'] = df.groupby(['firm'])['adjprice'].shift(4)
df[['q', 'adjprice', 'lprice']]
df.loc['ADT': 'ADTN', ['adjprice', 'lprice']].iloc[84:98]
# Out:
# Empty DataFrame
# Columns: [adjprice, lprice]
# Index: []

# %%
df.head()
# Out:
#    firm                   Name  N  Class Country\nof Origin Type of Asset  \
# 0  FLWS  1 800 Flowers Com Inc  1  Com A                 US         Stock
# 1  FLWS  1 800 Flowers Com Inc  1  Com A                 US         Stock
# 2  FLWS  1 800 Flowers Com Inc  1  Com A                 US         Stock
# 3  FLWS  1 800 Flowers Com Inc  1  Com A                 US         Stock
# 4  FLWS  1 800 Flowers Com Inc  1  Com A                 US         Stock
#
#   Sector NAICS\nlevel 1 Exchange / Src Sector\nEconomatica  \
# 0          Retail Trade         NASDAQ               Trade
# 1          Retail Trade         NASDAQ               Trade
# 2          Retail Trade         NASDAQ               Trade
# 3          Retail Trade         NASDAQ               Trade
# 4          Retail Trade         NASDAQ               Trade
#
#   Sector NAICS\nlast available  ...  adjprice originalprice  \
# 0                 Retail Trade  ...  7.125000      7.125000
# 1                 Retail Trade  ...  5.125000      5.125000
# 2                 Retail Trade  ...  4.984375      4.984375
# 3                 Retail Trade  ...  4.125000      4.125000
# 4                 Retail Trade  ...  8.000000      8.000000
#
#    sharesoutstanding  fiscalmonth    year  cto  lprice         r        r2  \
# 0          64097.913          9.0  2000.0  1.0     NaN       NaN       NaN
# 1          64170.913         12.0  2000.0  2.0     NaN       NaN       NaN
# 2          64185.913          3.0  2000.0  3.0     NaN       NaN       NaN
# 3          64187.163          6.0  2000.0  4.0     NaN       NaN       NaN
# 4          64187.163          9.0  2001.0  1.0   7.125  0.115832  0.115832
#
#     qdate
# 0  2000Q1
# 1  2000Q2
# 2  2000Q3
# 3  2000Q4
# 4  2001Q1
#
# [5 rows x 34 columns]

# %% [markdown]
# # ¿Cuántas empresas hay en cada industria?

# %%
# Obtenemos el conteo de las industrias utilizando el dataset que solo contiene
# la información de las empresas, basándonos en la columna de su industria

a = usfirms['Sector NAICS\nlevel 1'].value_counts()

a
# Out:
# Manufacturing                                                               1567
# Finance and Insurance                                                        703
# Information                                                                  263
# Retail Trade                                                                 152
# Professional, Scientific, and Technical Services                             145
# Administrative and Support and Waste Management and Remediation Services     133
# Mining, Quarrying, and Oil and Gas Extraction                                104
# Wholesale Trade                                                               79
# Utilities                                                                     77
# Transportation and Warehousing                                                69
# Accommodation and Food Services                                               69
# Real Estate and Rental and Leasing                                            68
# Health Care and Social Assistance                                             64
# Construction                                                                  45
# Arts, Entertainment, and Recreation                                           22
# Other Services (except Public Administration)                                 16
# Agriculture, Forestry, Fishing and Hunting                                    16
# Educational Services                                                          14
# -                                                                              2
# Name: Sector NAICS\nlevel 1, dtype: int64

# %% [markdown]
# For each industry (and for all industries), what can you say about the typical firm size in terms of market value and book value? How much these variables change within each industry? How firm size (in market value) is distributed?

# %%
# Calculamos las variables para cada instancia de los datos
df['Book'] = df['totalassets'] - df['totalliabilities']
df['Market'] = df['originalprice'] * df['sharesoutstanding']
df['OPM'] = (df['revenue'] - df['cogs'] - df['sgae'] - df['otheropexp']) / df['revenue']

# %% [markdown]
# En la siguiente gráfica podemos observar cómo es que existen sectores de mercado que sobresalen mucho del promedio en cuanto al book value, como lo son Finance and Insurance y Other.

# %%
import plotly.express as px
mask = df['q']=='2022q2' 

px.bar(df[mask], x = 'Sector\nEconomatica', y = 'Book', color ="Sector\nEconomatica",title="Gráfica de book value por cada sector del mercado (Q2 2022)")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="83018c1a-fd93-45e2-a17a-d57d8015822a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83018c1a-fd93-45e2-a17a-d57d8015822a")) {                    Plotly.newPlot(                        "83018c1a-fd93-45e2-a17a-d57d8015822a",                        [{"alignmentgroup":"True","hovertemplate":"Sector\nEconomatica=%{x}<br>Book=%{y}<extra></extra>","legendgroup":"Trade","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Trade","offsetgroup":"Trade","orientation":"v","showlegend":true,"textposition":"auto","x":["Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade"],"xaxis":"x","y":[null,null,156367.0,426543.0,704805.0,1528508.0,9353.0,2909680.0,4070600.0,131402000.0,99071.67199999999,1383006.0,469366.0,517864.0,1417206.0,1149355.0,5398283.0,2410400.0,3266000.0,164754.0,2325000.0,-3387230.0,4192760.0,228374.0,-2658000.0,1676300.0,-220298.0,2767000.0,270415.0,980328.0,721342.0,52398.0,499717.0,1764985.0,639534.0,353593.0,98539.0,5136353.0,716156.0,299931.0,-706000.0,5400637.0,108254.0,864000.0,2240838.0,1106200.0,1352405.0,373687.0,58610.0,252778.0,141179.0,554391.0,433607.0,682000.0,4353054.0,2006000.0,20513000.0,2068096.0,1505000.0,75506000.0,181714.0,416793.0,2194606.0,-14880.218,1512333.0,541828.0,5961624.0,8241500.0,-4180309.0,221389.0,375586.0,47306.299999999996,34122.399999999994,676288.0,-10103.0,685754.0,15587.517999999998,95874.0,3178700.0,1817998.0,1114942.0,1494286.0,3215000.0,1450700.0,2454000.0,600338.0,3653563.0,187700.0,1064498.0,182395.0,1056691.0,2004500.0,236726.0,712171.0,313277.0,4227000.0,20582000.0,306106.0,-1709000.0,7333.312999999998,140937.0,null,409238.0,438500.0,53649.0,1188831.2429999998,1613097.0,null,3218.0,24285.863999999994,115000.0,1628900.0,4375.0,12382.314,65207.0,4456000.0,1308982.0,181039.0,398405.0,229782.0,-258769.0,4698000.0,97965.0,5605000.0,273269.0,null,-6877000.0,62425.0,3278000.0,742740.0,-1472000.0,32787.0,703073.0,347000.0,1307965.0,762700.0,15 ...

# %% [markdown]
# Hablando del valor de mercado podemos ver un cambio interesante, ya que ahora notamos una menor disparidad entre los sectores de mercado con valores más altos. Se observa que ahora Finance and Insurance representa el tercer sector con valores más altos, contrastando así con su primer puesto en la gráfica anterior.

# %%
px.bar(df[mask], x = 'Sector\nEconomatica', y = 'Market', color = 'Sector\nEconomatica', title="Gráfica de market value por cada sector del mercado (Q2 2022)")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e0b5f1e7-a396-4fc1-bbfb-38a08be7e39f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0b5f1e7-a396-4fc1-bbfb-38a08be7e39f")) {                    Plotly.newPlot(                        "e0b5f1e7-a396-4fc1-bbfb-38a08be7e39f",                        [{"alignmentgroup":"True","hovertemplate":"Sector\nEconomatica=%{x}<br>Market=%{y}<extra></extra>","legendgroup":"Trade","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Trade","offsetgroup":"Trade","orientation":"v","showlegend":true,"textposition":"auto","x":["Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade","Trade"],"xaxis":"x","y":[613927.47441,129792.54504,216601.53725999998,355087.62059999997,853560.9050400001,3024338.63716,16657.01982,10496147.309249999,13561511.65888,1080624045.7401998,95320.607,1893914.6394999998,647830.0977999999,29634973.793999996,1116051.17216,3697169.097,7402085.87283,3747714.342,5579064.7578,356480.1812,6518363.66632,41881188.76288,4188592.5395200006,152494.63643,6157561.2752,3530573.1470399997,397389.51553000003,14678728.45233,250283.30469000002,606399.36687,8424532.144159999,126656.44628,645248.1739800001,2346728.3245800002,2049193.9664099999,1387126.4241900002,255934.45142000003,9277410.6363,9000997.41495,1795360.75268,14239778.211740002,14401338.95616,375254.74566,4259585.0199,6879094.32372,21288832.843200002,2203685.7037299997,1486847.06902,14603471.11664,621962.7377599999,198551.2573,190779.34295999998,315401.36306,1064000.0,25825502.10816,5483346.4202,212303282.19672,22470981.327,2892669.3332499997,121505898.79684,197139.52701,918813.7845600001,6069341.470450001,10182.329678299999,3865106.34048,784963.15014,55714148.09792,34997058.210599996,14047123.06057,318251.53799999994,571023.4812299999,36578.61379,191972.61903,1424601.96032,133416.99615999998,425482.83504,21049.704800000003,376003.11942,28734253.11744,3299247.4550700006,6294246.580200001,6664849.20824,2386384.29225,9310580.8582,3032057.04512,685203 ...

# %%
df_sorted_market = df.sort_values(by=['Market'], ascending=False)

# %%
mask = df['q']=='2022q2' 
df_top10_market = df[mask]
df_top10_book = df[mask]
df_sorted_market =  df_top10_market.sort_values('Market', ascending=False).head(10)
df_sorted_book = df_top10_book.sort_values('Book', ascending=False).head(10)

# %% [markdown]
# A continuación podemos ver el listado de las 10 firmas con un mayor valor de libro.

# %%
df_sorted_book["firm"]
# Out:
# 160545      JPM
# 38153       BAC
# 14573     GOOGL
# 67410         C
# 109530      XOM
# 314185      WFC
# 189073     MSFT
# 64890       CVX
# 30863         T
# 15653      AMZN
# Name: firm, dtype: object

# %% [markdown]
# 2.2.1.2

# %% [markdown]
# Para este punto, intento hallar cuales son las medidas que tienen una mayor relación con las ventas que tiene una firma.
# En este ejercicio es posible identificar una alta correlación con el cogs, el sgae y el stock holder equity.

# %%
df_corrs = df.corr()["revenue"]
#df_corrs.rename = ["Metrica", "Valor"]
df_corrs.sort_values( ascending = False)
df_corrs

#Calculate and explain earnings per share deflated by price.
# dividir entre stock prize
# Out:
# N                   -0.016230
# revenue              1.000000
# cogs                 0.931408
# sgae                 0.677615
# otheropexp           0.333943
# extraincome         -0.025453
# finexp               0.379055
# incometax            0.449182
# totalassets          0.323492
# totalliabilities     0.275417
# shortdebt            0.291061
# longdebt             0.378894
# stockholderequity    0.595631
# adjprice            -0.002771
# originalprice        0.151463
# sharesoutstanding    0.494759
# fiscalmonth          0.003523
# year                -0.055865
# cto                  0.002382
# lprice              -0.002971
# r                    0.030197
# r2                   0.030197
# Book                 0.595626
# Market               0.615881
# OPM                  0.005302
# Name: revenue, dtype: float64
